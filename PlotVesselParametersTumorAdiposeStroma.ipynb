# %%
# import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.gridspec as gridspec
from numpy import genfromtxt
from scipy.stats import ttest_rel
from matplotlib.colors import ListedColormap
from matplotlib.ticker import FuncFormatter
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt

set_limits = False
sns.set_style("ticks", {'axes.grid' : False})


my_pal = {"adipose": "khaki", "stroma": "darkgray", "tumor":"crimson"}

fig = plt.figure(figsize=(15,5), constrained_layout=False)
gs = gridspec.GridSpec(nrows=1, 
                       ncols=5, 
                       figure=fig,
                       wspace=0.3,
                       hspace=0.15)


ax = fig.add_subplot(gs[0, 0])
counts = pd.read_csv("measurements/measurements_vessel_full_slide.csv")
#print(counts[counts['region']=='tumor'])


ax = sns.boxplot(y="density", x="region", palette=my_pal, data=counts, saturation=1)
ax.set(ylabel="", xlabel="")
ax.set(xticklabels=[])
ax.set_title('density (#/mm$^2$)', fontsize=16)
if set_limits:
    plt.ylim(0, 300)

cat1 = counts[counts['region']=='tumor']['density']
cat2 = counts[counts['region']=='adipose']['density']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 0, 1 
ymin, ymax = ax.get_ylim()
diff = ymax - ymin
y, h, col = ymax - 3*(diff/15), diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.3f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

cat1 = counts[counts['region']=='adipose']['density']
cat2 = counts[counts['region']=='stroma']['density']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 1, 2 
y, h, col = ymax - 2*(diff/15), diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.3f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

cat1 = counts[counts['region']=='tumor']['density']
cat2 = counts[counts['region']=='stroma']['density']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 0, 2 
y, h, col = ymax - diff/15, diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.3f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off




ax2 = fig.add_subplot(gs[0, 2])
ax2 = sns.boxplot(x="region", y="mean_thickness", palette=my_pal, data=counts, saturation=1)
ax2.set(ylabel="", xlabel="")
#ax2.get_legend().remove()
ax2.set(xticklabels=[])
ax2.set_title('mean thickness (μm)', fontsize=16)
if set_limits:
    plt.ylim(6, 22)

cat1 = counts[counts['region']=='tumor']['mean_thickness']
cat2 = counts[counts['region']=='adipose']['mean_thickness']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 0, 1 
ymin, ymax = ax2.get_ylim()
diff = ymax - ymin
y, h, col = ymax - 3*(diff/15), diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.3f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

cat1 = counts[counts['region']=='adipose']['mean_thickness']
cat2 = counts[counts['region']=='stroma']['mean_thickness']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 1, 2 
y, h, col = ymax - 2*(diff/15), diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.3f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

cat1 = counts[counts['region']=='tumor']['mean_thickness']
cat2 = counts[counts['region']=='stroma']['mean_thickness']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 0, 2 
y, h, col = ymax - diff/15, diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.3f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off





ax3 = fig.add_subplot(gs[0, 1])
ax3 = sns.boxplot(x="region", y="mean_area", palette=my_pal, data=counts, saturation=1)
ax3.set(ylabel="", xlabel="")
# ax3.get_legend().remove()
ax3.set(xticklabels=[])
ax3.set_title('mean area (μm$^2$)', fontsize=16)
if set_limits:
    plt.ylim(0, 6000)

cat1 = counts[counts['region']=='tumor']['mean_area']
cat2 = counts[counts['region']=='adipose']['mean_area']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 0, 1 
ymin, ymax = ax3.get_ylim()
diff = ymax - ymin
y, h, col = ymax - 3*(diff/15), diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.3f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

cat1 = counts[counts['region']=='adipose']['mean_area']
cat2 = counts[counts['region']=='stroma']['mean_area']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 1, 2 
y, h, col = ymax - 2*(diff/15), diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.3f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

cat1 = counts[counts['region']=='tumor']['mean_area']
cat2 = counts[counts['region']=='stroma']['mean_area']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 0, 2 
y, h, col = ymax - diff/15, diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.2f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off





ax4 = fig.add_subplot(gs[0, 4])
ax4 = sns.boxplot(x="region", y="mean_circularity", palette=my_pal, data=counts, saturation=1)
ax4.set(ylabel="", xlabel="")
ax4.set(xticklabels=[])
ax4.set_title('mean circularity', fontsize=16)
if set_limits:
    plt.ylim(0.4, 0.7)

cat1 = counts[counts['region']=='tumor']['mean_circularity']
cat2 = counts[counts['region']=='adipose']['mean_circularity']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 0, 1 
ymin, ymax = ax4.get_ylim()
diff = ymax - ymin
y, h, col = ymax - 3*(diff/15), diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.2f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

cat1 = counts[counts['region']=='adipose']['mean_circularity']
cat2 = counts[counts['region']=='stroma']['mean_circularity']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 1, 2 
y, h, col = ymax - 2*(diff/15), diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.2f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

cat1 = counts[counts['region']=='tumor']['mean_circularity']
cat2 = counts[counts['region']=='stroma']['mean_circularity']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 0, 2 
y, h, col = ymax - diff/15, diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.2f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off





ax5 = fig.add_subplot(gs[0, 3])
ax5 = sns.boxplot(x="region", y="mean_axis_ratio", palette=my_pal, data=counts, saturation=1)
ax5.set(ylabel="", xlabel="")
# ax5.get_legend().remove()
ax5.set(xticklabels=[])
ax5.set_title('mean axis ratio', fontsize=16)
if set_limits:
    plt.ylim(2.0, 3.6)


cat1 = counts[counts['region']=='tumor']['mean_axis_ratio']
cat2 = counts[counts['region']=='adipose']['mean_axis_ratio']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 0, 1 
ymin, ymax = ax5.get_ylim()
diff = ymax - ymin
y, h, col = ymax - 3*(diff/15), diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.2f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

cat1 = counts[counts['region']=='adipose']['mean_axis_ratio']
cat2 = counts[counts['region']=='stroma']['mean_axis_ratio']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 1, 2
y, h, col = ymax - 2*(diff/15), diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.2f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

cat1 = counts[counts['region']=='tumor']['mean_axis_ratio']
cat2 = counts[counts['region']=='stroma']['mean_axis_ratio']
t, p = ttest_rel(cat1, cat2, axis=0, nan_policy='propagate')
x1, x2 = 0, 2
y, h, col = ymax - diff/15, diff/60, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1, c=col)
if p < 0.05:
    plt.text((x1+x2)*.5, y+h, "p<0.05", ha='center', va='bottom', color=col, fontsize=12)
else:
    plt.text((x1+x2)*.5, y+h, "p={:.2f}".format(p), ha='center', va='bottom', color=col, fontsize=12)

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off





legend_elements = [Patch(facecolor='crimson', edgecolor='black', label='Tumour', alpha=1),
                   Patch(facecolor='khaki', edgecolor='black', label='Adipose', alpha=1),
                   Patch(facecolor='darkgray', edgecolor='black', label='Stroma', alpha=1)]
fig.legend(handles=legend_elements, loc='upper center', ncol=3, bbox_to_anchor=(0.5, 1), prop={'size': 20, 'weight':'normal'})


plt.subplots_adjust(top = 0.78, bottom = 0.05, right = 0.98, left = 0.02)

for item in ([ax.xaxis.label, ax.yaxis.label] + ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(14)
for item in ([ax2.xaxis.label, ax2.yaxis.label] + ax2.get_xticklabels() + ax2.get_yticklabels()):
    item.set_fontsize(14)
for item in ([ax3.xaxis.label, ax3.yaxis.label] + ax3.get_xticklabels() + ax3.get_yticklabels()):
    item.set_fontsize(14)
for item in ([ax4.xaxis.label, ax4.yaxis.label] + ax4.get_xticklabels() + ax4.get_yticklabels()):
    item.set_fontsize(14)
for item in ([ax5.xaxis.label, ax5.yaxis.label] + ax5.get_xticklabels() + ax5.get_yticklabels()):
    item.set_fontsize(14)



plt.show()

fig.savefig("measurements/boxplot_tumor_adipose_stroma.pdf", bbox_inches = 'tight')
